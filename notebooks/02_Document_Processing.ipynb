# %% [markdown]
# ## Collecting Data from different PDF and store it as Embeddings

# %%
from pypdf import PdfReader

# %% [markdown]
# ## read pdf

# %%
reader = PdfReader("Annual-Report202425.pdf")
num_pages = len(reader.pages)
print(num_pages)
reader
# Out:
# 264

# %%
pages = reader.pages[9]
print(pages.extract_text())
reader.pages
# Out:
# obtained by considering the usual principal
# status (ps) and the subsidiary status (ss)
# together. The workers in the usual status
# (ps+ss) include (a) the persons who worked for
# a relatively long part of the 365 days preceding
# the date of survey and (b) the persons from
# among the remaining population who had
# worked at least for 30 days during the
# reference period of 365 days preceding the
# date of survey.
# 1.5   India's vast livestock and poultry resources, as
# th
# detailed in the 20  Livestock Census, underline
# their pivotal socio-economic role, particularly in
# rural areas. The 303.76 million bovines (including
# cattle, buffalo, mithun, and yak) signify the
# backbone of dairy production and draught power
# in agriculture. Sheep (74.26 million) and goats
# (148.88 million) contribute to meat, milk, and wool
# production, essential for arid and semi-arid
# regions, while pigs (9.06 million) cater to niche
# markets in northeastern and tribal areas. The
# ...

# %%
text=""
for page in reader.pages:
    text+=page.extract_text() +"\n"
print(text)
# Out:
# Annual ReportAnnual Report
# 2024-252024-25
# Annual Report
# 2024-25
# DEPARTMENT OF ANIMAL HUSBANDRY AND DAIRYING
# MINISTRY OF FISHERIES, ANIMAL HUSBANDRY AND DAIRYING
# GOVERNMENT OF INDIA
#
# ANNUAL REPORT
# 2024-25
# Department of Animal Husbandry and Dairying
# Ministry of Fisheries, Animal Husbandry and Dairying
# Government of India
#
# Ch.
# No.
# Name of Chapter Pages
# 1  Overview of achievements  1-10
# 11-27
# 29-67
# 69-88
# 89-103
# 105-127
# 129-140
# 141-144
# 145-147
# 149-158
# 159-161
# 163-171
# 173-192
# 193-205
# 207-210
# 211-216
# 2.  Organisation
# 3. Cattle Development
# 4. Dairying Development
# 5. Animal Husbandry
# 6. Livestock Health
# 7. Animal Husbandry Statistics
# 8. Trade Matters
# 9. Scheduled Caste Sub Plan and Tribal Sub Plan
# 10. Empowerment of Women
# 11. International Cooperation
# 12. Animal Welfare
# 13. Credit, Extension and Publicity
# 14. Departmental Accounting Organisation
# 15. Activities of Parliament Section
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(chunk_size=1000,
                                               chunk_overlap=200,
                                               length_function=len)
all_splits = text_splitter.create_documents([text])
# Out:
# c:\Users\Amit\anaconda3\envs\py310\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 from langchain.text_splitter import RecursiveCharacterTextSplitter
# ----> 2 text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(chunk_size=1000,
#       3                                                chunk_overlap=200,
#       4                                                length_function=len)
#       5 all_splits = text_splitter.create_documents([text])
#
# File c:\Users\Amit\anaconda3\envs\py310\lib\site-packages\langchain_text_splitters\base.py:221, in TextSplitter.from_tiktoken_encoder(cls, encoding_name, model_name, allowed_special, disallowed_special, **kwargs)
# ...

# %%
all_splits
# Out:
# [Document(metadata={}, page_content='Annual ReportAnnual Report\n2024-252024-25\nAnnual Report\n2024-25\nDEPARTMENT OF ANIMAL HUSBANDRY AND DAIRYING\nMINISTRY OF FISHERIES, ANIMAL HUSBANDRY AND DAIRYING\nGOVERNMENT OF INDIA\n\nANNUAL REPORT \n2024-25\nDepartment of Animal Husbandry and Dairying\nMinistry of Fisheries, Animal Husbandry and Dairying\nGovernment of India'),
# ...

# %%
import json 
with open("C:\\krishisahayi\\lang-chain-bot\\data\\scraped_chunks.json", "a", encoding="utf-8") as f:
    json.dump(
        all_splits,
        f,
        ensure_ascii=False,
        indent=2
    )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 import json
#       2 with open("C:\krishisahayi\lang-chain-bot\data\scraped_chunks.json","w",encoding="utf-8") as f:
# ----> 3     json.dump([doc for doc in all_splits],f,ensure_ascii= False,indent=2)
#
# File c:\Users\Amit\anaconda3\envs\py310\lib\json\__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
# ...
